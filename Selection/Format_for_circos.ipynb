# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
full_chr7 = pd.DataFrame(index=range(3273176),columns=range(1))
full_chr7.rename(columns = {0:'value'}, inplace = True)

# %%
full_chr7.insert(0, 'Pos', range(1, 1 + len(full_chr7)))

# %%
full_chr7
# Out:
#              Pos value
# 0              1   NaN
# 1              2   NaN
# 2              3   NaN
# 3              4   NaN
# 4              5   NaN
# ...          ...   ...
# 3273171  3273172   NaN
# 3273172  3273173   NaN
# 3273173  3273174   NaN
# 3273174  3273175   NaN
# 3273175  3273176   NaN
#
# [3273176 rows x 2 columns]

# %%
chr7_range = pd.read_table("chr7.txt", header = 0)

# %%
chr7_range
# Out:
#      chr    start      end  value
# 0   chr7        0    27450      0
# 1   chr7    27451    28197      1
# 2   chr7    28198    66973      0
# 3   chr7    66974    67537      1
# 4   chr7    67538   293717      0
# 5   chr7   293718   294767      1
# 6   chr7   294767   315726      0
# 7   chr7   315727   316422      1
# 8   chr7   316423   349822      0
# 9   chr7   349823   350740      1
# 10  chr7   350741   632387      0
# 11  chr7   632387   632856      1
# 12  chr7   632857  1323427      0
# 13  chr7  1323428  1324402      1
# 14  chr7  1324403  1553597      0
# 15  chr7  1553598  1554044      1
# 16  chr7  1554045  1805139      0
# 17  chr7  1805140  1805420      1
# 18  chr7  1805421  1806636      0
# 19  chr7  1806636  1807770      1
# 20  chr7  1807771  1822046      0
# 21  chr7  1822047  1822405      1
# 22  chr7  1822406  1931212      0
# 23  chr7  1931213  1932105      1
# 24  chr7  1932106  2228689      0
# 25  chr7  2228690  2229715      1
# ...

# %%
#full_chr7["value"]= 0
full_chr7["value"][27451:28197]= 1
full_chr7["value"][66974:67537]= 1
full_chr7["value"][293718:294767]= 1
full_chr7["value"][315727:316422]= 1
full_chr7["value"][349823:350740]= 1
full_chr7["value"][632387:632856]= 1
full_chr7["value"][1323428:1324402]= 1
full_chr7["value"][1553598:1554044]= 1
full_chr7["value"][1805140:1805420]= 1
full_chr7["value"][1806636:1807770]= 1
full_chr7["value"][1822047:1822405]= 1
full_chr7["value"][1931213:1932105]= 1
full_chr7["value"][2228690:2229715]= 1
full_chr7["value"][2481192:2481779]= 1
full_chr7["value"][2550929:2551745]= 1
full_chr7["value"][2605828:2606216]= 1
full_chr7["value"][2662880:2663214]= 1
full_chr7["value"][2694673:2695481]= 1
full_chr7["value"][3148137:3148875]= 1
full_chr7["value"][3149388:3150149]= 1
# Out:
# /home/taliadoros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/taliadoros/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /home/taliadoros/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
full_chr7
# Out:
#              Pos value
# 0              1   NaN
# 1              2   NaN
# 2              3   NaN
# 3              4   NaN
# 4              5   NaN
# ...          ...   ...
# 3273171  3273172   NaN
# 3273172  3273173   NaN
# 3273173  3273174   NaN
# 3273174  3273175   NaN
# 3273175  3273176   NaN
#
# [3273176 rows x 2 columns]

# %%
plt.plot(full_chr7["Pos"], full_chr7["value"],linewidth=7.0)

# %%
chr7_range2 = pd.read_table("chr7_full2.txt", header = 0)
